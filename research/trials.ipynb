# %%
d = {"key":"value", "key1":"value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"value", "key1":"value1"})

# %%
d2.key1
# Out:
# 'value1'

# %%
from ensure import ensure_annotations

@ensure_annotations
def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(10,4)
# Out:
# 40

# %%
get_product(x=10, y="a")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_product(x=10, y="a")
#
# File e:\MLProject\End-to-End-Machine-Learning-Project-with-MLflow\End-to-End-Machine-Learning-Project-with-MLflow\mlProject\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000028C10A4E200> does not match annotation type <class 'int'>
