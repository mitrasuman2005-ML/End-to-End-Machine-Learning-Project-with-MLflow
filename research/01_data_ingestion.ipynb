# %%
import os

# %%
# %pwd
# Out:
# 'e:\\MLProject\\End-to-End-Machine-Learning-Project-with-MLflow\\End-to-End-Machine-Learning-Project-with-MLflow\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'e:\\MLProject\\End-to-End-Machine-Learning-Project-with-MLflow\\End-to-End-Machine-Learning-Project-with-MLflow'
